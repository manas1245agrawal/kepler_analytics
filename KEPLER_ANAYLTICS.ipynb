# %% [markdown]
# <a href="https://colab.research.google.com/github/manas1245agrawal/kepler_analytics/blob/vivek/KEPLER_ANAYLTICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#let's start the anaylsis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv('astrotrain.csv')

# %%
print("Hello" worldwadj)
# Out:
# Hello

# %%
df
# Out:
#                                      SUBSURVEY      SNID              IAUC  \
# 0                                               10473255  NULL
# 1                                                2110040  NULL
# 2                                                9966178  NULL
# 3                                               19732134  NULL
# 4                                                1582526  NULL
# ...                                        ...       ...               ...
# 3358                                            10905975  NULL
# 3359                                            32688008  NULL
# 3360                                            22850707  NULL
# 3361                                             3135401  NULL
# 3362                                             8179580  NULL
#
#       FAKE         RA       DECL  PIXSIZE  NXPIX  NYPIX  CCDNUM  ...  \
# 0        2  53.468451 -28.349424     0.27     -9     -9      44  ...
# 1        2  53.508185 -28.470810     0.27     -9     -9      50  ...
# 2        2  35.077432  -6.979272     0.27     -9     -9      51  ...
# 3        2  52.852204 -27.184372     0.27     -9     -9       3  ...
# 4        2  36.932302  -5.248342     0.27     -9     -9      55  ...
# ...    ...        ...        ...      ...    ...    ...     ...  ...
# 3358     2  52.069245 -28.209427     0.27     -9     -9      33  ...
# 3359     2  36.848725  -4.312594     0.27     -9     -9      23  ...
# 3360     2  34.841945  -4.750525     0.27     -9     -9      23  ...
# 3361     2  10.491751 -43.552455     0.27     -9     -9      18  ...
# 3362     2  41.737693  -1.003020     0.27     -9     -9      37  ...
#
#       SIM_PEAKMAG_z  SIM_EXPOSURE_g  SIM_EXPOSURE_r  SIM_EXPOSURE_i  \
# 0         23.664705               1               1               1
# 1         24.363064               1               1               1
# 2         23.319248               1               1               1
# 3         22.917084               1               1               1
# 4         22.626780               1               1               1
# ...             ...             ...             ...             ...
# 3358      23.892733               1               1               1
# 3359      22.991283               1               1               1
# 3360      22.115574               1               1               1
# 3361      22.710224               1               1               1
# 3362      23.637630               1               1               1
#
#       SIM_EXPOSURE_z  SIM_GALFRAC_g  SIM_GALFRAC_r  SIM_GALFRAC_i  \
# 0                  1   2.378913e+00       1.384469       1.228777
# 1                  1   3.250000e-14       7.968017       3.885829
# 2                  1   5.848331e-01       0.558739       0.499326
# 3                  1   4.299130e+00      13.111013      19.559818
# 4                  1   2.718171e-01       0.285706       0.416343
# ...              ...            ...            ...            ...
# 3358               1   1.134495e+00       3.363861       9.255050
# 3359               1   2.127631e+00       5.020600       7.200759
# 3360               1   2.399753e+00       2.653501       3.059909
# 3361               1   8.653105e-01       0.819891       1.291712
# 3362               1   6.916079e-01       1.016441       1.365743
#
#       SIM_GALFRAC_z  SIM_SUBSAMPLE_INDEX
# 0          1.400711                   -9
# 1          3.697690                   -9
# 2          0.525232                   -9
# 3         34.610160                   -9
# 4          0.543132                   -9
# ...             ...                  ...
# 3358      13.862765                   -9
# 3359      12.036779                   -9
# 3360       3.577755                   -9
# 3361       1.546110                   -9
# 3362       1.360222                   -9
#
# [3363 rows x 82 columns]
# Warning: Total number of columns (82) exceeds max_columns (20) limiting to first (20) columns.
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['SNID'].plot(kind='hist', bins=20, title='SNID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['RA'].plot(kind='hist', bins=20, title='RA')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['DECL'].plot(kind='hist', bins=20, title='DECL')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('SUBSURVEY').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='index', y='SNID', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='SNID', y='RA', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='RA', y='DECL', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='DECL', y='CCDNUM', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['SNID']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('SUBSURVEY')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='SUBSURVEY', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('SNID')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['RA']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('SUBSURVEY')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='SUBSURVEY', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('RA')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['DECL']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('SUBSURVEY')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='SUBSURVEY', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('DECL')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['CCDNUM']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('SUBSURVEY')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='SUBSURVEY', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('CCDNUM')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['SNID'].plot(kind='line', figsize=(8, 4), title='SNID')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['RA'].plot(kind='line', figsize=(8, 4), title='RA')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['DECL'].plot(kind='line', figsize=(8, 4), title='DECL')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['SUBSURVEY'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='index', y='SUBSURVEY', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['SUBSURVEY'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='SNID', y='SUBSURVEY', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['SUBSURVEY'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='RA', y='SUBSURVEY', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['SUBSURVEY'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='DECL', y='SUBSURVEY', inner='box', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
